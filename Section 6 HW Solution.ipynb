# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
mov=pd.read_csv("Section6-Homework-Data.csv",encoding='cp1252')

# %%
mov.describe()
# Out:
#        Budget ($mill)  IMDb Rating  MovieLens Rating   Overseas%  \
# count      608.000000   608.000000        608.000000  608.000000
# mean        92.467928     6.923849          3.340378   57.698849
# std         59.421407     0.925890          0.454071   12.334237
# min          0.600000     3.600000          1.490000   17.200000
# 25%         45.000000     6.375000          3.037500   49.900000
# 50%         80.000000     6.900000          3.365000   58.200000
# 75%        130.000000     7.600000          3.672500   66.300000
# max        300.000000     9.200000          4.500000  100.000000
#
#             Profit%  Runtime (min)  US ($mill)  Gross % US
# count    608.000000     608.000000  608.000000  608.000000
# mean     719.278783     117.781250  167.135197   42.301151
# std     1942.807248      23.179122   92.465903   12.334237
# min        7.700000      30.000000    0.000000    0.000000
# 25%      201.850000     100.000000  106.950000   33.700000
# ...

# %%
mov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 18 columns):
# Day of Week               608 non-null object
# Director                  608 non-null object
# Genre                     608 non-null object
# Movie Title               608 non-null object
# Release Date              608 non-null object
# Studio                    608 non-null object
# Adjusted Gross ($mill)    608 non-null object
# Budget ($mill)            608 non-null float64
# Gross ($mill)             608 non-null object
# IMDb Rating               608 non-null float64
# MovieLens Rating          608 non-null float64
# Overseas ($mill)          608 non-null object
# Overseas%                 608 non-null float64
# Profit ($mill)            608 non-null object
# Profit%                   608 non-null float64
# Runtime (min)             608 non-null int64
# US ($mill)                608 non-null float64
# Gross % US                608 non-null float64
# ...

# %%
mov.columns=['DayOfWeek','Director','Genre', 'MovieTitle', 'ReleaseDate',
       'Studio', 'AdjustedGross', 'Budget', 'Gross',
       'IMDbRating', 'MovieLensRating', 'Overseas', 'Overseas%',
       'Profit', 'Profit%', 'Runtime', 'USCollection',
       'Gross%US']

# %%
vis1=sns.factorplot(data=mov,x='DayOfWeek',kind='count',size=10)

# %%
# Seeing unique values
mov.Studio.unique()
# Out:
# array(['Buena Vista Studios', 'Lionsgate', 'Sony', 'Universal',
#        'Paramount Pictures', 'WB', 'Weinstein Company',
#        'UA Entertainment', 'WB/New Line', 'New Line Cinema', 'Fox',
#        'TriStar', 'Relativity Media', 'Screen Gems', 'StudioCanal',
#        'Fox Searchlight Pictures', 'MiraMax', 'Path_ Distribution',
#        'DreamWorks', 'Lionsgate Films', 'Revolution Studios',
#        'Dimension Films', 'USA', 'Lionsgate/Summit',
#        'Sony Picture Classics', 'Pacific Data/DreamWorks', 'Disney',
#        'Art House Studios', 'Colombia Pictures', 'Gramercy Pictures',
#        'Summit Entertainment', 'Vestron Pictures', 'MGM', 'Orion', 'IFC',
#        'New Market Films'], dtype=object)

# %%
len(mov.Studio.unique())
# Out:
# 36

# %%
mov.Genre.unique()
# Out:
# array(['action', 'comedy', 'adventure', 'horror', 'animation',
#        'biography', 'drama', 'musical', 'sci-fi', 'crime', 'romance',
#        'fantasy', 'mystery', 'thriller', 'documentary'], dtype=object)

# %%
len(mov.Genre.unique())
# Out:
# 15

# %%
mov2= mov[(mov.Studio=='Fox')| (mov.Studio=='WB')]

# %%
mov2.Studio.unique()
# Out:
# array(['WB', 'Fox'], dtype=object)

# %%
genre_filter=['action','comedy','adventure','animation','drama']

# %%
studio_filter=['Buena Vista Studios','Sony', 'Universal',
       'Paramount Pictures', 'WB','Fox',]

# %%
mov2=mov[mov.Genre.isin(genre_filter)]

# %%
mov2.Genre.unique()
# Out:
# array(['action', 'comedy', 'adventure', 'animation', 'drama'],
#       dtype=object)

# %%
mov3=mov2[mov2.Studio.isin(studio_filter)] # ~~~~ Adding studio filter to already Genre filtered mov2 ~~~~~~
# Adding filter to filtered data

# %%
mov3.Studio.unique()
# Out:
# array(['Buena Vista Studios', 'Sony', 'Universal', 'WB',
#        'Paramount Pictures', 'Fox'], dtype=object)

# %%
sns.boxplot(data=mov3, x='Genre', y='Gross%US')

# %%
sns.set(style='darkgrid',palette='muted',color_codes=True)

# %%
sns.boxplot(data=mov3, x='Genre', y='Gross%US')

# %%
sns.boxplot(data=mov3, x='Genre', y='Gross%US',orient='v',color='lightgray')

# %%
sns.boxplot(data=mov3, x='Genre', y='Gross%US',orient='v',color='lightgray')
plt.setp(ax.artists,alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-4914d502c3a7> in <module>()
#       1 sns.boxplot(data=mov3, x='Genre', y='Gross%US',orient='v',color='lightgray')
# ----> 2 plt.setp(ax.artists,alpha=0.5)
#
# AttributeError: module 'matplotlib' has no attribute 'setp'

# %%
sns.boxplot(data=mov3, x='Genre', y='Gross%US',orient='v',color='lightgray')
plt.setp(ax.artists,alpha=0.5)
sns.stripplot(x='Genre',y='Gross%US',data=mov3,jitter=True, size=6,linewidth=0,hue='Studio')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-5373d46dc019> in <module>()
#       1 sns.boxplot(data=mov3, x='Genre', y='Gross%US',orient='v',color='lightgray')
# ----> 2 plt.setp(ax.artists,alpha=0.5)
#       3 sns.stripplot(x='Genre',y='Gross%US',data=mov3,jitter=True, size=6,linewidth=0,hue='Studio')
#
# AttributeError: module 'matplotlib' has no attribute 'setp'

# %%
ax= sns.boxplot(data=mov3, x='Genre', y='Gross%US',orient='v',color='lightgray',showfliers=False)
#ax=plt.gca() 
plt.setp(ax.artists,alpha=0.5)
sns.stripplot(x='Genre',y='Gross%US',data=mov3,jitter=True, size=6,linewidth=0,hue='Studio')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-0a10f4b41618> in <module>()
#       1 ax= sns.boxplot(data=mov3, x='Genre', y='Gross%US',orient='v',color='lightgray',showfliers=False)
#       2 #ax=plt.gca()
# ----> 3 plt.setp(ax.artists,alpha=0.5)
#       4 sns.stripplot(x='Genre',y='Gross%US',data=mov3,jitter=True, size=6,linewidth=0,hue='Studio')
#
# AttributeError: module 'matplotlib' has no attribute 'setp'

# %%
ax= sns.boxplot(data=mov3, x='Genre', y='Gross%US',orient='v',color='lightgray')
sns.stripplot(x='Genre',y='Gross%US',data=mov3,jitter=True, size=6,linewidth=0,hue='Studio',alpha=0.7)
ax.axes.set_title('Domestic Gross % by Genre',fontsize=30)
ax.set_xlabel('Genre',fontsize=20)
ax.set_ylabel("Gross%US",fontsize=20)
# Out:
# Text(0,0.5,'Gross%US')

# %%
ax= sns.boxplot(data=mov3, x='Genre', y='Gross%US',orient='v',color='lightgray')
sns.stripplot(x='Genre',y='Gross%US',data=mov3,jitter=True, size=6,linewidth=0,hue='Studio',alpha=0.7)
ax.axes.set_title('Domestic Gross % by Genre',fontsize=30)
ax.set_xlabel('Genre',fontsize=20)
ax.set_ylabel("Gross%US",fontsize=20)

ax.legend(bbox_to_anchor=(1.05,1),loc=2)

# %%
# haven't been able to get transparenct, error with setp
