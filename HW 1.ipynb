# %%
#Testing law of large numbers for N random normally distributed nos, mean=0, variance=1
#Create a python script that'll count how many nos. fall b/w -1 & 1& divide that by total N
# E(X)= 68.2%
# Check that mean (Xn) -> E(X) as you rerun your script while increasing N

# %%
import numpy as np
from numpy.random import randn # has to be numpy.random, np.random will give an error
N=0
count=0
m=0
mean= None
while N<100:
    x= randn()
    print("value of x is ",x)
    print ("count currently is ", N)
    N= N+1
    if x >-1
        if x < 1:
            count= count+1
mean= count/N
print("The mean value is ", mean)
# Out:
# value of x is  -0.2791241743696078
# count currently is  0
# value of x is  0.5970487679139241
# count currently is  1
# value of x is  -0.7891957393583077
# count currently is  2
# value of x is  0.45522341926743404
# count currently is  3
# value of x is  0.008980661761735445
# count currently is  4
# value of x is  -1.206853445153281
# count currently is  5
# value of x is  -0.5915230393102184
# count currently is  6
# value of x is  -0.1595835612394267
# count currently is  7
# value of x is  0.8981478296542313
# count currently is  8
# value of x is  2.3366542571911917
# count currently is  9
# value of x is  0.5509628835534413
# count currently is  10
# value of x is  0.9101967525042092
# count currently is  11
# value of x is  -1.0500280308935077
# count currently is  12
# value of x is  0.8209446914334154
# count currently is  13
# value of x is  -0.1569964813290302
# count currently is  14
# value of x is  0.11482834434955355
# count currently is  15
# ...

# %% [markdown]
# ---

# %%
#Trying the same thing all over again for N=200
#redoing even the importing for practice
import numpy as np
from numpy.random import randn
count=0
a=0
t=0
mean=0
v=None
# taking <200, since indexing in python starts at 0
while count<200:
    v= randn()
    print("count # ", count, " Random value is ", v)
    count =count+1
    if v>-1 and v<1:
        t=t+1
mean= t/count
print("Mean value is ", mean)
# Out:
# count #  0  Random value is  -0.14659185689350118
# count #  1  Random value is  1.638761379371876
# count #  2  Random value is  -0.3392283973603715
# count #  3  Random value is  0.9788122040309637
# count #  4  Random value is  -0.2097492781812548
# count #  5  Random value is  1.0787037223027516
# count #  6  Random value is  -0.6428381720271648
# count #  7  Random value is  -1.0658483073588763
# count #  8  Random value is  0.5703028478318604
# count #  9  Random value is  -1.4376083801324469
# count #  10  Random value is  0.8352431340319925
# count #  11  Random value is  0.11188204237040339
# count #  12  Random value is  1.2297507817634699
# count #  13  Random value is  -1.254366098257971
# count #  14  Random value is  -0.1941534264264288
# count #  15  Random value is  0.9534134675399061
# count #  16  Random value is  -0.03269575916113927
# count #  17  Random value is  0.045858373651547844
# count #  18  Random value is  0.17461108824314575
# ...

# %% [markdown]
# ---

# %%
#increasing N

# %%
import numpy as np
from numpy.random import randn
c=0
a=0
t=0
mean=0
v=None
while c<400:
    v= randn()
    print("count # ", c, " Random value is ", v)
    c =c+1
    if v>-1 and v<1:
        t=t+1
mean= t/c
print("Mean value is ", mean)
# Out:
# count #  0  Random value is  -0.02019215500656823
# count #  1  Random value is  0.3669637330005718
# count #  2  Random value is  0.3461391846628786
# count #  3  Random value is  -1.5629208086150084
# count #  4  Random value is  0.013123955011724763
# count #  5  Random value is  0.09266389323504344
# count #  6  Random value is  -0.9127107381756265
# count #  7  Random value is  -0.851539217489131
# count #  8  Random value is  0.4319107344419456
# count #  9  Random value is  -1.6556995414920421
# count #  10  Random value is  -0.09815527250051292
# count #  11  Random value is  -0.34771417079346234
# count #  12  Random value is  1.9161298727778107
# count #  13  Random value is  1.558730221050958
# count #  14  Random value is  -0.10063946384879621
# count #  15  Random value is  0.6022192592004166
# count #  16  Random value is  1.7156681129794098
# count #  17  Random value is  -0.30048466773316956
# count #  18  Random value is  0.9780156501548918
# ...
