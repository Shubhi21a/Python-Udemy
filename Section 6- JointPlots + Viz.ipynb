# %%
import pandas as pd

# %%
import os

# %%
movies=pd.read_csv("Movie-Ratings.csv")

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns=['Film','Genre','CriticsRating','AudienceRating','BudgetMillions','Year']

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null object
# Genre             559 non-null object
# CriticsRating     559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
# Changing category
movies.Film= movies.Film.astype('category')
movies.Genre= movies.Genre.astype('category')
movies.Year=movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null category
# CriticsRating     559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
movies.Genre.cat.categories # for unique values
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %% [markdown]
# ---

# %% [markdown]
# # Starting with visualization

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings 
warnings.filterwarnings('ignore')

# %%
#Joint Plot ~~~~~~

# %%
j=sns.jointplot(data=movies,x='CriticsRating',y='AudienceRating')

# %%
j=sns.jointplot(data=movies,x='CriticsRating',y='AudienceRating',kind='hex')
# shows clusters, here, associated with high points in the distribution

# %%
#~~~~~ Histograms

# %%
# Already know this method
m1=sns.distplot(movies.AudienceRating)

# %%
m1=sns.distplot(movies.AudienceRating, bins=15)

# %%
m2=sns.distplot(movies.CriticsRating, bins=15)

# %%
n1=plt.hist(movies.AudienceRating, bins=15)

# %%
sns.set_style("darkgrid") ##adding style, darkgrid
# style is white for graphs we had so far
n1=plt.hist(movies.AudienceRating, bins=15)

# %% [markdown]
# ---

# %%
# Stacked Histograms

# %%
h1= plt.hist(movies.BudgetMillions)
plt.show()

# %%
h1= plt.hist(movies.BudgetMillions, edgecolor='k') ## to get border
plt.show()

# %%
movies[movies.Genre=='Drama']
# Out:
#                                     Film  Genre  CriticsRating  \
# 10                            88 Minutes  Drama              5
# 11                    A Dangerous Method  Drama             79
# 13                        A Serious Man   Drama             89
# 18                          Albert Nobbs  Drama             53
# 23                       All Good Things  Drama             33
# 26                          An Education  Drama             94
# 27                             Anonymous  Drama             46
# 47                    Black Swan          Drama             88
# 53                             Brothers   Drama             61
# 55                                Buried  Drama             86
# 56                             Burlesque  Drama             36
# 62                            Changeling  Drama             62
# 74                        Country Strong  Drama             20
# 84                             Dear John  Drama             29
# ...

# %%
movies[movies.Genre=='Drama'].BudgetMillions
# Out:
# 10      30
# 11      20
# 13       7
# 18       8
# 23      20
# 26       8
# 27      30
# 47      13
# 53      26
# 55       2
# 56      55
# 62      55
# 74      15
# 84      25
# 96      37
# 99      25
# 112     60
# 116     21
# 117      5
# 119     31
# 120     40
# 128      1
# 131     24
# 132     21
# 151     33
# 158     16
# 171      7
# 195     15
# 199     35
# 213     10
#       ...
# 437     13
# 442     20
# 444      2
# 445     20
# 446     40
# 450     65
# 457     40
# 466     45
# 467     11
# 470     60
# 480     39
# 482     32
# 483     68
# 484     50
# 487      0
# 488      4
# 489    150
# 490     16
# 492     25
# 508     20
# 509     10
# 511      2
# 516     25
# 523     26
# 527     70
# 529     66
# 532     38
# 534     21
# 541     15
# 545      2
# Name: BudgetMillions, Length: 101, dtype: int64

# %%
plt.hist(movies[movies.Genre=='Drama'].BudgetMillions)
plt.show()

# %%
plt.hist(movies[movies.Genre=='Action'].BudgetMillions)
plt.hist(movies[movies.Genre=='Thriller'].BudgetMillions)
plt.show()

# %%
plt.hist(movies[movies.Genre=='Action'].BudgetMillions,bins=15)
plt.hist(movies[movies.Genre=='Drama'].BudgetMillions,bins=15)
plt.hist(movies[movies.Genre=='Thriller'].BudgetMillions,bins=15)
plt.show()

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
plt.hist(movies[movies.Genre=='Action'].BudgetMillions,bins=15)
plt.hist(movies[movies.Genre=='Drama'].BudgetMillions,bins=15)
plt.hist(movies[movies.Genre=='Thriller'].BudgetMillions,bins=15)
plt.show()

# %%
plt.hist( movies[movies.Genre=='Action'].BudgetMillions,
          movies[movies.Genre=='Drama'].BudgetMillions,
          movies[movies.Genre=='Thriller'].BudgetMillions, bins=15
          stacked=True)
plt.show()
# Out:
#   File "<ipython-input-60-658e8a2ec1e9>", line 4
#     stacked=True)
#           ^
# SyntaxError: invalid syntax

# %%
list1= list() # can also create by list1=[]
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre==gen].BudgetMillions)
print(list1)
# Out:
# [2       20
# 5      200
# 15      35
# 29      20
# 30      20
# 33     237
# 36      45
# 39      45
# 40      70
# 45     150
# 49      68
# 52      17
# 58     140
# 60      85
# 63      40
# 66     125
# 67      25
# 69      40
# 70      90
# 73      30
# 76     163
# 77      13
# 81      25
# 83      20
# 86      45
# 94      30
# 98      33
# 101     75
# 102     30
# 106     45
#       ...
# 433    138
# 435     50
# 439     40
# 441     80
# 443    150
# 448     25
# 451     40
# 454    145
# 458    100
# 472    150
# 473      6
# 474      0
# 477    100
# 479     75
# 493    150
# 495     35
# 499    150
# 500    195
# 501    210
# 502     30
# 504    170
# 512     35
# 514     95
# 528     75
# 530     25
# 531    130
# 542     35
# 546    150
# 547    160
# 557     24
# Name: BudgetMillions, Length: 154, dtype: int64, 1      105
# 3       18
# 19     200
# 21      45
# 24      40
# 32      78
# 46      20
# 65      38
# 68     140
# 130     73
# 165     12
# 166    125
# ...

# %%
h=plt.hist(list1)

# %%
h=plt.hist(list1,bins=30,stacked=True)

# %%
h=plt.hist(list1,bins=30,stacked=True, edgecolor='k')

# %%
h=plt.hist(list1,bins=30,stacked=True, edgecolor='k', rwidth=1)

# %%
list1= list() 
mylabels=list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre==gen].BudgetMillions)
    mylabels.append(gen)
    
h=plt.hist(list1,bins=30,stacked=True, edgecolor='k', rwidth=1,label=mylabels)
plt.legend()
plt.show()

# %% [markdown]
# ---

# %%
# KDE plot

# %%
vis1=sns.lmplot(data=movies,x='CriticsRating', y='AudienceRating',fit_reg=False, hue='Genre',size=6, aspect=1)

# %%
k1=sns.kdeplot(movies.CriticsRating, movies.AudienceRating)

# %%
k1=sns.kdeplot(movies.CriticsRating, movies.AudienceRating,shade=True)

# %%
k1=sns.kdeplot(movies.CriticsRating, movies.AudienceRating,shade=True,shadelowest=False) # supposed to show the grid

# %%
k1=sns.kdeplot(movies.CriticsRating, movies.AudienceRating,shade=True,shadelowest=False, cmap='Reds')

# %%
# k1=sns.kdeplot(movies.CriticsRating, movies.AudienceRating,shade=True,shadelowest=False, cmap='Reds') 
#Tip
k1b=sns.kdeplot(movies.CriticsRating, movies.AudienceRating,shadelowest=False, cmap='Reds')

# %%
k1=sns.kdeplot(movies.CriticsRating, movies.AudienceRating,shade=True,shadelowest=False, cmap='Reds') 
#Tip
k1b=sns.kdeplot(movies.CriticsRating, movies.AudienceRating,shadelowest=False, cmap='Reds') 
# this is supposed to be a smoother, more professional version, but I think  both look just fine

# %% [markdown]
# ---

# %% [markdown]
# # Working with subplots()

# %%
# we're using seaborn 
k1=sns.kdeplot(movies.BudgetMillions,movies.AudienceRating)

# %%
# we see the stretch of the ratings to interpret this

# %%
sns.set_style("dark")
k1=sns.kdeplot(movies.BudgetMillions,movies.AudienceRating)

# %%
k2=sns.kdeplot(movies.BudgetMillions,movies.CriticsRating)

# %%
f, ax=plt.subplots(1,2)

# %%
f, ax=plt.subplots(2,3) # 2 rows, 3 columns

# %%
f,ax=plt.subplots(1,2,figsize=(12,6)) # 12- height, 6- length

# %%
f,ax=plt.subplots(1,2,figsize=(12,6))
k1=sns.kdeplot(movies.BudgetMillions,movies.AudienceRating)
k2=sns.kdeplot(movies.BudgetMillions,movies.CriticsRating)

# %%
f,axes=plt.subplots(1,2,figsize=(12,6))
k1=sns.kdeplot(movies.BudgetMillions,movies.AudienceRating,ax=axes[0])
k2=sns.kdeplot(movies.BudgetMillions,movies.CriticsRating,ax=axes[1])
#fig is chart that we're trying to create, axis is an array that tells where the chart is to be plotted

# %%
# for example
f,axes=plt.subplots(2,2,figsize=(12,6))
k11=sns.kdeplot(movies.BudgetMillions,movies.AudienceRating,ax=axes[0][0])
k21=sns.kdeplot(movies.BudgetMillions,movies.CriticsRating,ax=axes[0][1])

# %%
f,axes=plt.subplots(1,2,figsize=(12,6))
k1=sns.kdeplot(movies.BudgetMillions,movies.AudienceRating,ax=axes[0])
k2=sns.kdeplot(movies.BudgetMillions,movies.CriticsRating,ax=axes[1])
k1.set(xlim=(-20,160))
# Out:
# [(-20, 160)]

# %%
f,axes=plt.subplots(1,2,figsize=(12,6),sharex=True,sharey=True) #they now share axes
k1=sns.kdeplot(movies.BudgetMillions,movies.AudienceRating,ax=axes[0])
k2=sns.kdeplot(movies.BudgetMillions,movies.CriticsRating,ax=axes[1])
k1.set(xlim=(-20,160))
# Out:
# [(-20, 160)]

# %% [markdown]
# ---

# %%
# Violin Plots

# %%
z=sns.boxplot(data=movies,x='Genre',y='CriticsRating')

# %%
z=sns.violinplot(data=movies,x='Genre',y='CriticsRating')

# %%
z=sns.boxplot(data=movies[movies.Genre=='Drama'],x='Year',y='CriticsRating')

# %%
z=sns.violinplot(data=movies[movies.Genre=='Drama'],x='Year',y='CriticsRating')

# %% [markdown]
# ---

# %% [markdown]
# # Creating a Facet Grid

# %%
g=sns.FacetGrid(movies,row='Genre',hue='Genre')

# %%
g=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre') #col and not column

# %%
plt.scatter(movies.CriticsRating,movies.AudienceRating)

# %%
#these 2 have to be run together, for this to work
g=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
g=g.map(plt.scatter,'CriticsRating','AudienceRating')
#g.map(func, *args, **kwargs) - * args: any no. of arguments
# g=g.map(plt.scatter,movies.CriticsRating,movies.AudienceRating)

# movies already mentioned in first line, so we don't need movies.CriticsRating

# %%
# can populate with any type of chart
g=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
g=g.map(plt.hist,'BudgetMillions')

# %%
# Back to the scatterplot
g=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
kws=dict(s=50,linewidth=0.5,edgecolor='black')
g=g.map(plt.scatter,'CriticsRating','AudienceRating')

# %%
kws
# Out:
# {'s': 50, 'linewidth': 0.5, 'edgecolor': 'black'}

# %%
#these 2 have to be run together, for this to work
g=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
kws=dict(s=50,linewidth=0.5,edgecolor='black')
g=g.map(plt.scatter,'CriticsRating','AudienceRating',**kws)
g.set(xlim=(0,100),ylim=(0,100))

# %%
#these 2 have to be run together, for this to work
g=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
kws=dict(s=50,linewidth=0.5,edgecolor='black')
g=g.map(plt.scatter,'CriticsRating','AudienceRating',**kws)
g.set(xlim=(0,100),ylim=(0,100))

for ax in g.axes.flat:
    ax.plot((0,100),(0,100),c="gray",ls="--")
# axes- matrix to access elements on the axes, flat: helps convert this 2 dimensional thing to simple list-like for loop
